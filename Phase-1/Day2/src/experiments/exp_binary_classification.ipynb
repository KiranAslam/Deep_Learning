# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from neuron import neuron
from Losses import BinaryCrossEntropy
from trainer import Trainer

X,y=make_classification(
    n_samples=500,
    n_features=2,
    n_redundant=0,
    n_clusters_per_class=1,
    random_state=42
)

y=y.reshape(-1,1)

plt.scatter(X[:,0],X[:,1],c=y.flatten(), cmap='viridis')
plt.title("Initial data")
plt.show()
input_features=X.shape[1]
model=neuron(input_features)
loss_fn=BinaryCrossEntropy()
trainer=Trainer(X,model,loss_fn,lr=0.01)

print("Training started...")
losses=trainer.train(X,y,epochs=1000)

plt.plot(losses)
plt.title("trainering loss curve")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()
# Out:
# Training started...
# Epoch : 0 | loss: 0.6912
# Epoch : 100 | loss: 0.5266
# Epoch : 200 | loss: 0.4558
# Epoch : 300 | loss: 0.4183
# Epoch : 400 | loss: 0.3956
# Epoch : 500 | loss: 0.3805
# Epoch : 600 | loss: 0.3698
# Epoch : 700 | loss: 0.3618
# Epoch : 800 | loss: 0.3557
# Epoch : 900 | loss: 0.3509
